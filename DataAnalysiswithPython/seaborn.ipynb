# %% [markdown]
# ### Data Visualization with Seaborn
# Seaborn is a python visualization library based on Matplotlib that provides a high-level interface for drawing attractive and informative statistical graphics. Seaborn helps in creating complex visualizations with just a few lines of code. In this lesson, we will cover the basics of Seaborn, including creating various types of plots and customizing them.

# %%
import seaborn as sns

# %%
##Basic plotting with Seaborn
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
#Create a scatter plot
import matplotlib.pyplot as plt
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.title("Scatter plot of Total Bill vs Tips")
plt.show()

# %%
##Line Plot
sns.lineplot(x='size', y='total_bill', data=tips)
plt.title("Line plot of Size vs Total Bill")
plt.show()

# %%
#Categorical Plots
#Bar plot
sns.barplot(x='day', y='total_bill', data=tips)
plt.title("Bar plot of Total Bill by Day")
plt.show()

# %%
sns.boxplot(x='day', y='total_bill', data=tips)
plt.title("Box plot of Total Bill by Day")
plt.show()

# %%
#Voilin Plot
sns.violinplot(x='day', y='total_bill', data=tips)
plt.title("Violin plot of Total Bill by Day")
plt.show()

# %%
#Histograms
sns.histplot(tips['total_bill'], bins=10, kde=True)
plt.title("Histogram of Total Bill by Day")
plt.show()

# %%
#KDE Plot
sns.kdeplot(tips['total_bill'], fill=True)
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %%
#Pair Plot - Relationship between all the variables to different variables
sns.pairplot(tips)

# %%
corr = tips[['total_bill','tip','size']].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
import pandas as pd
df = pd.read_csv('sales_data1.csv')

# %%
df['Total_Sales'] = df['Unit_Price'] * df['Quantity_Sold']

# %%
#Plot total sales by product
df
# Out:
#      Product_ID   Sale_Date Sales_Rep Region  Sales_Amount  Quantity_Sold  \
# 0          1052  2023-02-03       Bob  North       5053.97             18
# 1          1093  2023-04-21       Bob   West       4384.02             17
# 2          1015  2023-09-21     David  South       4631.23             30
# 3          1072  2023-08-24       Bob  South       2167.94             39
# 4          1061  2023-03-24   Charlie   East       3750.20             13
# ..          ...         ...       ...    ...           ...            ...
# 995        1010  2023-04-15   Charlie  North       4733.88              4
# 996        1067  2023-09-07       Bob  North       4716.36             37
# 997        1018  2023-04-27     David  South       7629.70             17
# 998        1100  2023-12-20     David   West       1629.47             39
# 999        1086  2023-08-16     Alice   East       4923.93             48
#
#     Product_Category  Unit_Cost  Unit_Price Customer_Type  Discount  \
# 0          Furniture     152.75      267.22     Returning      0.09
# 1          Furniture    3816.39     4209.44     Returning      0.11
# 2               Food     261.56      371.40     Returning      0.20
# 3           Clothing    4330.03     4467.75           New      0.02
# 4        Electronics     637.37      692.71           New      0.08
# ..               ...        ...         ...           ...       ...
# 995             Food    4943.03     5442.15     Returning      0.29
# 996         Clothing    1754.32     1856.40           New      0.21
# 997         Clothing     355.72      438.27     Returning      0.06
# 998      Electronics    3685.03     3743.39           New      0.01
# 999             Food    2632.58     2926.68     Returning      0.14
#
#     Payment_Method Sales_Channel Region_and_Sales_Rep  Total_Sales
# 0             Cash        Online            North-Bob      4809.96
# 1             Cash        Retail             West-Bob     71560.48
# 2    Bank Transfer        Retail          South-David     11142.00
# 3      Credit Card        Retail            South-Bob    174242.25
# 4      Credit Card        Online         East-Charlie      9005.23
# ..             ...           ...                  ...          ...
# 995           Cash        Online        North-Charlie     21768.60
# 996  Bank Transfer        Retail            North-Bob     68686.80
# 997  Bank Transfer        Online          South-David      7450.59
# 998  Bank Transfer        Online           West-David    145992.21
# 999           Cash        Online           East-Alice    140480.64
#
# [1000 rows x 15 columns]

# %%
plt.figure(figsize=(10,6))
sns.barplot(x='Product_Category',y='Total_Sales', data=df, estimator=sum)
plt.title("Bar plot of Total Sales by Product Category")
plt.xlabel("Product Category")
plt.ylabel("Total Sales")
plt.show()
