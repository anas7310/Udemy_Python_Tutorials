# %% [markdown]
# ### 5 number summary and Box plot

# %%
## minimum, maximum, median, Q1, Q3, IQR

# %%
import numpy as np

# %%
list_marks = [45, 32, 76, 89, 56, 54, 32,89,90, 87,67, 54, 45, 98,99,67,74]
minimum, Q1, median, Q3, maximum = np.quantile(list_marks,[0,0.25,0.50,0.75,1.0])

# %%
minimum, Q1, median, Q3, maximum
# Out:
# (np.float64(32.0),
#  np.float64(54.0),
#  np.float64(67.0),
#  np.float64(89.0),
#  np.float64(99.0))

# %%
IQR = Q3-Q1

# %%
IQR
# Out:
# np.float64(35.0)

# %%
lower_fence = Q1 - 1.5*IQR
higher_fence = Q3 + 1.5*IQR

# %%
lower_fence
# Out:
# np.float64(1.5)

# %%
higher_fence
# Out:
# np.float64(141.5)

# %%
import seaborn as sns

# %%
sns.boxplot(list_marks)
# Out:
# <Axes: >

# %%
list_marks_1 = [-100,-70,45, 32, 76, 89, 56, 54, 32,89,90, 87,67, 54, 45, 98,99,67,74,150,170,190]

# %%
sns.boxplot(list_marks_1)
# Out:
# <Axes: >
