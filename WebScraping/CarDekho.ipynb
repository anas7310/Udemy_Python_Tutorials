# %% [markdown]
# Web Scraping on CarDekho.com used cars url: https://www.cardekho.com/used-cars+in+new-delhi

# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd
import time
import random

headers=({
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit\
    /537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.36'
})

def get_basic_info(content_list):
    basic_info=[]
    for item in content_list:
        basic_info.append(item.findall('div', attrs={
            'class':'bottom_container'
        }))
    return basic_info

# %%
response=requests.get('https://www.cardekho.com/used-cars+in+new-delhi',headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'})
if response.status_code == 200:
    # Parse the HTML content
    soup = bs(response.content, 'html.parser')
    print(soup.prettify())  # Print the formatted HTML content
else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# <!DOCTYPE html>
# <html lang="en" translate="no">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="notranslate" name="google"/>
#   <title>
#    Used Cars in New Delhi, 6864 Second Hand Cars in New Delhi for Sale - CarDekho
#   </title>
#   <meta content="Used Cars in New Delhi - Check second hand cars in New Delhi. We have 6864 certified old cars in New Delhi for sale. Check price &amp; buy the best 2nd hand car at CarDekho." name="description"/>
#   <link crossorigin="anonymous" href="https://staticcont.cardekho.com" rel="preconnect dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://stimg.cardekho.com" rel="preconnect dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://connect.facebook.net" rel="preconnect dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://www.googletagmanager.com" rel="preconnect dns-prefetch"/>
#   <link crossorigin="anonymous" href="https://www.google-analytics.com" rel="preconnect dns-prefetch"/>
# ...

# %%
divs = soup.find_all('div', class_=['gsc_col-xs-12 holder truncate', 'gsc_col-xs-12 holder', 'gsc_col-xs-12'])

# %%
len(divs)
# Out:
# 30

# %%
for div in divs:
        print(div.prettify())
# Out:
# <div class="gsc_col-xs-12 gsc_col-sm-8 gsc_col-md-9 gsc_col-lg-9 rightSidebarHeading">
#  <div>
#  </div>
#  <div class="gsc_row">
#   <div class="TopHeaderUCR">
#    <div class="gsc_col-xs-12 headingDiv">
#     <div class="headingSection">
#      <div class="headingcontainer">
#       <h1>
#        6864 Second Hand Cars in New Delhi
#       </h1>
#      </div>
#      <div class="subtextDiv autoheight">
#       <div class="posR content-wrapper content-truncated">
#        <div class="content-text">
#         <p class="SubText">
#          There are 772 certified second-hand cars in New Delhi currently available for sale of brands like
#          <a href="https://www.cardekho.com/used-maruti+cars+in+new-delhi" title="Maruti">
#           Maruti
#          </a>
#          ,
#          <a href="https://www.cardekho.com/used-hyundai+cars+in+new-delhi" title="Hyundai">
#           Hyundai
#          </a>
#          ,
# ...

# %%
for i in range(len(divs)):
    # Check if there is an anchor tag within the div
    if divs[i].a:
        # Print the href attribute of the anchor tag
        print(divs[i].a['href'])
    else:
        print("No anchor tag found in div index:", i)
# Out:
# https://www.cardekho.com/used-maruti+cars+in+new-delhi
# https://www.cardekho.com/used-maruti+cars+in+new-delhi
# No anchor tag found in div index: 2
# /used-car-details/used-Bmw-x1-sdrive18i-m-sport-cars-Gurgaon_b13f39e9-3b60-494f-b504-24c9f1c65b82.htm?adId=16783&adType=1
# /used-car-details/used-Bmw-x1-sdrive18i-m-sport-cars-Gurgaon_b13f39e9-3b60-494f-b504-24c9f1c65b82.htm?adId=16783&adType=1
# /used-car-details/used-Mahindra-bolero-neo-n8-cars-New-Delhi_ef870a6d-ec00-45c0-aea3-bcbc0d5cff93.htm?adId=17077&adType=41
# /used-car-details/used-Kia-sonet-gravity-cars-New-Delhi_e79bf2c1-4381-4411-b7ca-3e1bff59de9d.htm
# /used-cars+0-lakh-to-2-lakh+in+new-delhi
# /used-car-details/used-Kia-sonet-htx-diesel-at-cars-New-Delhi_af689c4d-4a9c-4ffe-8247-bfdcb0067786.htm
# /used-car-details/used-Kia-syros-htk-opt-turbo-cars-New-Delhi_b2f88181-777f-46b4-9d45-3f47acc8bc5b.htm
# ...

# %%
s=bs(requests.get('https://www.cardekho.com/usedCars',headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}).text)
url='https://www.cardekho.com/cars/'
for i in s.find_all('a',class_='BrIconUsedCar'):
  print(url+i.text.replace(' ','_'))

# %%
soup = bs(response.text)
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
page_number = 1
names = []
prices = []
years = []
motors = []
mileages = []

# %%
for i in range(9):
    base_url = "https://www.cardekho.com/used-cars+in+new-delhi".format(page_number)
    response = requests.get(base_url, headers=headers)
    html_soup = bs(response.text, 'html.parser')
    content_list = html_soup.find_all('div', attrs={'class': 'bottom_container'})
    print('content list = ', content_list[0])
    # basic_info = get_basic_info(content_list)
    page_number = page_number + 1
    time.sleep(random.randint(1,2))
# Out:
# content list =  <div class="bottom_container"><div class="title_heart_section"><div class="titlebox hover"><h3 class="title"><a href="/used-car-details/used-Bmw-x1-sdrive18i-m-sport-cars-Gurgaon_b13f39e9-3b60-494f-b504-24c9f1c65b82.htm?adId=16783&amp;adType=1" rel="noreferrer" target="_blank" title="2024 BMW X1 sDrive18i M Sport">2024<!-- --> <!-- -->BMW X1<!-- --> <!-- -->sDrive18i M Sport</a></h3><div class="dotsDetails">9,480<!-- --> kms   <span>•</span>   <!-- -->Petrol<!-- -->   <span>•</span>   <!-- -->Automatic</div></div><div class="shortlist NewUcrShortList" id="shortlistHeartIcon"><img alt="Search" decoding="async" fetchpriority="high" height="30px" loading="eager" src="https://stimg.cardekho.com/usedcar/imgs/Shortlist-Line.svg" width="30px"/></div></div><div class="Price hover"><div class="priceAssured"><p>₹48 Lakh</p></div></div><div class="discounts"></div><div class="bottomFlexSection"><div class="distanceText"><img alt="map" height="12px" src="https://stimg.cardekho.co
# ...

# %%
print
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>
